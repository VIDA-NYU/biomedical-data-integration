# %% [markdown]
# # Getting Started
#
# ## Data Harmonization with `bdikit`
#
# Data harmonization is the process of integrating and aligning data from different sources into a consistent format to ensure compatibility and interoperability across data analyses and systems. `bdikit` is a library the helps with key data harmonization steps:
# - *Schema Mapping*: In this step, data from various sources are mapped to a unified schema or model. This involves identifying equivalent table columns and establishing relationships between disparate datasets.
# - *Value Mapping (Data Standardization)*: This step involves converting data into a common format or structure, using consistent naming conventions, units, and coding systems to ensure uniformity.
#
# In this example, we describe how `bdikit` can be used to harmonize datasets from two papers:
# - Dou et al. 2020, Proteogenomic Characterization of Endometrial Carcinoma. https://pubmed.ncbi.nlm.nih.gov/32059776/ (CPTAC Discovery)
# - Dou et al. 2023, Proteogenomic insights suggest druggable pathways in endometrial carcinoma. https://pubmed.ncbi.nlm.nih.gov/37567170/ (CPTAC Confirmatory)

# %% [markdown]
# #### Loading the data
#
# First, import the `bdikit` library and other libraries.

# %%
import bdikit as bdi
import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='44b43c35-dbb0-4aa9-a2c3-a454e65a8fba'>
#   <div id="a8724be6-0a80-49a1-8487-8c5bb83ee4c9" data-root-id="44b43c35-dbb0-4aa9-a2c3-a454e65a8fba" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4d1373c8-dc28-4bd9-be67-a294b32b3da1":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"44b43c35-dbb0-4aa9-a2c3-a454e65a8fba"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"333a598a-aca6-4d27-b8a9-b1e15589e41c","attributes":{"plot_id":"44b43c35-dbb0-4aa9-a2c3-a454e65a8fba","comm_id":"d44b3e58f7a34b39baa20237e0acfd99","client_comm_id":"da4dce5c3ab94ec4bf40c758fa24dbbf"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"4d1373c8-dc28-4bd9-be67-a294b32b3da1","roots":{"44b43c35-dbb0-4aa9-a2c3-a454e65a8fba":"a8724be6-0a80-49a1-8487-8c5bb83ee4c9"},"root_ids":["44b43c35-dbb0-4aa9-a2c3-a454e65a8fba"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# Next, we load our source data using Pandas and select some columns we are interested in.

# %%
df_source = pd.read_csv("./datasets/Dou-ucec-discovery.csv")
df_source.head(5)
# Out:
#     idx Proteomics_Participant_ID Case_excluded  Proteomics_TMT_batch  \
# 0  S001                 C3L-00006            No                     2
# 1  S002                 C3L-00008            No                     4
# 2  S003                 C3L-00032            No                     1
# 3  S004                 C3L-00084           Yes                     3
# 4  S005                 C3L-00090            No                     3
#
#    Proteomics_TMT_plex Proteomics_TMT_channel Proteomics_Parent_Sample_IDs  \
# 0                    5                   128N                 C3L-00006-01
# 1                   16                   130N                 C3L-00008-01
# 2                    2                    131                 C3L-00032-01
# 3                   11                   129N                 C3L-00084-01
# 4                   12                   129C                 C3L-00090-01
#
#   Proteomics_Aliquot_ID Proteomics_Tumor_Normal Proteomics_OCT  ...  \
# 0         CPT0001460012                   Tumor             No  ...
# 1         CPT0001300009                   Tumor             No  ...
# 2         CPT0001420009                   Tumor             No  ...
# 3         CPT0000820012                   Tumor             No  ...
# 4         CPT0001140003                   Tumor             No  ...
#
#   RNAseq_R1_sample_type                                 RNAseq_R1_filename  \
# 0                 Tumor  170802_UNC31-K00269_0072_AHK3GVBBXX_TAGCTT_S17...
# 1                 Tumor  170802_UNC31-K00269_0072_AHK3GVBBXX_GGCTAC_S22...
# 2                 Tumor  170802_UNC31-K00269_0072_AHK3GVBBXX_GTCCGC_S18...
# 3                 Tumor  170818_UNC32-K00270_0050_AHL2FHBBXX_ATCACG_S5_...
# 4                 Tumor  170802_UNC31-K00269_0072_AHK3GVBBXX_GAGTGG_S10...
#
#                          RNAseq_R1_UUID RNAseq_R2_sample_type  \
# 0  8a1efc47-1c29-417f-a425-cdbd09565dcb                 Tumor
# 1  555725e8-cba5-4676-9b0a-80100cbf9f47                 Tumor
# 2  9ae968f3-691d-4db3-9977-1ab3e5af9085                 Tumor
# 3  b0a7cdf2-2ad8-4442-91b0-548ea4975554                 Tumor
# 4  8ce5618d-9ff6-40f9-aeea-8d8e1633ae38                 Tumor
#
#                                   RNAseq_R2_filename  \
# 0  170802_UNC31-K00269_0072_AHK3GVBBXX_TAGCTT_S17...
# 1  170802_UNC31-K00269_0072_AHK3GVBBXX_GGCTAC_S22...
# 2  170802_UNC31-K00269_0072_AHK3GVBBXX_GTCCGC_S18...
# 3  170818_UNC32-K00270_0050_AHL2FHBBXX_ATCACG_S5_...
# 4  170802_UNC31-K00269_0072_AHK3GVBBXX_GAGTGG_S10...
#
#                          RNAseq_R2_UUID miRNAseq_sample_type  \
# 0  8c3fe9b7-7acd-4867-8d9c-a8e5d1516eda                Tumor
# 1  15235b12-b67a-4678-acc4-ed03d642bd5e                Tumor
# 2  423b6b09-02aa-4f47-9241-f75c1dad1161                Tumor
# 3  c83987a5-1c13-4af4-b46c-218fe5f60c34                  NaN
# 4  06d3fd4a-a623-4146-8500-4f1f17235253                Tumor
#
#                           miRNAseq_UUID Methylation_available  \
# 0  37bcba98-1094-459e-83ae-c23a602416fb                   YES
# 1  492b50d8-ec35-46e7-a65d-06512aaee394                   YES
# 2  1794ff56-db2d-4d1a-8758-cab7fe3d98c1                   YES
# 3                                   NaN                   YES
# 4  a6524c2d-d7dd-4629-980e-b45dbdc92c49                   YES
#
#   Methylation_quality
# 0                PASS
# 1                PASS
# 2                PASS
# 3                PASS
# 4                PASS
#
# [5 rows x 179 columns]

# %% [markdown]
# Our goal is to harmonize the data from our source table (`dou.csv`) with the data from our target table `cao.csv`

# %%
df_target = pd.read_csv("./datasets/Dou-ucec-confirmatory.csv")
df_target.head(5)
# Out:
#          Idx    Case_id Case_excluded Batch  Plex ReporterName     Aliquot_ID  \
# 0  C3L-00086  C3L-00086            No    b4  16.0         128N  CPT0092460003
# 1  C3L-00898  C3L-00898            No    b4  14.0         128C  CPT0172200008
# 2  C3L-00943  C3L-00943            No    b4  15.0         130C  CPT0086090003
# 3  C3L-01064  C3L-01064            No    b3   9.0         129N  CPT0113430004
# 4  C3L-01277  C3L-01277            No    b4  13.0         130N  CPT0093170003
#
#    Group Discovery_study Age  ... Follow-up_additional_surgery_for_new_tumor  \
# 0  Tumor              No  56  ...                            n/a|No|No|No|No
# 1  Tumor              No  54  ...                            n/a|n/a|n/a|n/a
# 2  Tumor              No  63  ...                                n/a|n/a|n/a
# 3  Tumor              No  54  ...                                No|No|No|No
# 4  Tumor              No  61  ...                                  n/a|No|No
#
#   Follow-up_additional_treatment_radiation_therapy_for_new_tumor  \
# 0                                n/a|Yes|Yes|Yes|Yes
# 1                                    n/a|n/a|n/a|n/a
# 2                                        n/a|n/a|n/a
# 3                                       No|Yes|No|No
# 4                                         n/a|No|Yes
#
#   Follow-up_additional_treatment_pharmaceutical_therapy_for_new_tumor  \
# 0                                n/a|Yes|Yes|Yes|Yes
# 1                                    n/a|n/a|n/a|n/a
# 2                                        n/a|n/a|n/a
# 3                                    Yes|Yes|Yes|Yes
# 4                                         n/a|Yes|No
#
#    Follow-up_additional_treatment_immuno_for_new_tumor  \
# 0                                    n/a|No|No|No|No
# 1                                    n/a|n/a|n/a|n/a
# 2                                        n/a|n/a|n/a
# 3                                        No|No|No|No
# 4                                          n/a|No|No
#
#    Follow-up_days_from_date_of_collection_to_date_of_last_contact  \
# 0                      330.0|701.0|1046.0|1436.0|n/a
# 1                           396.0|746.0|982.0|1600.0
# 2                                 237.0|693.0|1039.0
# 3                          453.0|726.0|1062.0|1447.0
# 4                                  351.0|713.0|967.0
#
#            Follow-up_cause_of_death  \
# 0  n/a|n/a|n/a|n/a|Breast Carcinoma
# 1                   n/a|n/a|n/a|n/a
# 2                       n/a|n/a|n/a
# 3                   n/a|n/a|n/a|n/a
# 4                       n/a|n/a|n/a
#
#    Follow-up_days_from_date_of_initial_pathologic_diagnosis_to_date_of_death  \
# 0                             n/a|n/a|n/a|n/a|1578.0
# 1                                    n/a|n/a|n/a|n/a
# 2                                        n/a|n/a|n/a
# 3                                    n/a|n/a|n/a|n/a
# 4                                        n/a|n/a|n/a
#
#   Follow-up_days_from_date_of_initial_pathologic_diagnosis_to_date_of_additional_surgery_for_new_tumor  \
# 0                                n/a|n/a|n/a|n/a|n/a
# 1                                    n/a|n/a|n/a|n/a
# 2                                        n/a|n/a|n/a
# 3                                    n/a|n/a|n/a|n/a
# 4                                        n/a|n/a|n/a
#
#   Follow-up_procedure_type_of_new_tumor  \
# 0                   n/a|n/a|n/a|n/a|n/a
# 1                       n/a|n/a|n/a|n/a
# 2                           n/a|n/a|n/a
# 3                       n/a|n/a|n/a|n/a
# 4                           n/a|n/a|n/a
#
#   Follow-up_residual_tumor_after_surgery_for_new_tumor
# 0                                n/a|n/a|n/a|n/a|n/a
# 1                                    n/a|n/a|n/a|n/a
# 2                                        n/a|n/a|n/a
# 3                                    n/a|n/a|n/a|n/a
# 4                                        n/a|n/a|n/a
#
# [5 rows x 213 columns]

# %% [markdown]
# For this demo, we are going to focus on a subset of the columns.

# %%
column_names = [
    "Proteomics_Participant_ID",
    "Case_excluded",
    "Proteomics_TMT_channel",
    "Proteomics_Aliquot_ID",
    "Proteomics_Tumor_Normal",
    "Country",
    "Histologic_type",
    "Path_Stage_Primary_Tumor-pT",
    "Path_Stage_Reg_Lymph_Nodes-pN",
    "Clin_Stage_Dist_Mets-cM",
    "tumor_Stage-Pathological",
    "BMI",
    "Age",
    "Diabetes",
    "Race",
    "Ethnicity",
    "Gender",
    "Tumor_Site",
    "Tumor_Site_Other",
    "Tumor_Focality",
    "Tumor_Size_cm",
    "Estrogen_Receptor",
    "Progesterone_Receptor",
    "MLH1",
    "PMS2",
    "p53",
    "MLH1_Promoter_Hypermethylation",
    "Num_full_term_pregnancies",
    "ESTIMATE_StromalScore",
    "ESTIMATE_ESTIMATEScore",
    "CNV_class",
    "MSI_status",
    "POLE_subtype",
    "Genomics_subtype",
]
df_source = df_source[column_names]
df_source.head(5)
# Out:
#   Proteomics_Participant_ID Case_excluded Proteomics_TMT_channel  \
# 0                 C3L-00006            No                   128N
# 1                 C3L-00008            No                   130N
# 2                 C3L-00032            No                    131
# 3                 C3L-00084           Yes                   129N
# 4                 C3L-00090            No                   129C
#
#   Proteomics_Aliquot_ID Proteomics_Tumor_Normal        Country  \
# 0         CPT0001460012                   Tumor  United States
# 1         CPT0001300009                   Tumor  United States
# 2         CPT0001420009                   Tumor  United States
# 3         CPT0000820012                   Tumor            NaN
# 4         CPT0001140003                   Tumor  United States
#
#   Histologic_type Path_Stage_Primary_Tumor-pT Path_Stage_Reg_Lymph_Nodes-pN  \
# 0    Endometrioid              pT1a (FIGO IA)                           pN0
# 1    Endometrioid              pT1a (FIGO IA)                           pNX
# 2    Endometrioid              pT1a (FIGO IA)                           pN0
# 3  Carcinosarcoma                         NaN                           NaN
# 4    Endometrioid              pT1a (FIGO IA)                           pNX
#
#   Clin_Stage_Dist_Mets-cM  ...                        PMS2  \
# 0                     cM0  ...   Intact nuclear expression
# 1                     cM0  ...  Loss of nuclear expression
# 2                     cM0  ...   Intact nuclear expression
# 3                     NaN  ...                         NaN
# 4                     cM0  ...   Intact nuclear expression
#
#                     p53  MLH1_Promoter_Hypermethylation  \
# 0  Cannot be determined            Cannot be determined
# 1  Cannot be determined            Cannot be determined
# 2  Cannot be determined            Cannot be determined
# 3                   NaN                             NaN
# 4  Cannot be determined            Cannot be determined
#
#   Num_full_term_pregnancies ESTIMATE_StromalScore ESTIMATE_ESTIMATEScore  \
# 0                         1           2821.088429            7706.697310
# 1                         1           2714.248104            6346.448091
# 2                 4 or more           3856.501277           10459.413600
# 3                       NaN                   NaN                    NaN
# 4                 4 or more           3012.556593            7475.466867
#
#   CNV_class MSI_status POLE_subtype Genomics_subtype
# 0   CNV_LOW      MSI-H           No            MSI-H
# 1   CNV_LOW      MSI-H           No            MSI-H
# 2   CNV_LOW        MSS           No          CNV_low
# 3       NaN        MSS           No              NaN
# 4   CNV_LOW        MSS           No          CNV_low
#
# [5 rows x 34 columns]

# %% [markdown]
# #### Finding column matches between two tables
#
# `bdi-kit` offers a suite of functions to help with data harmonization tasks.
#
# For instance, it can help automatically discover one-to-one mappings between the source and target dataset columns.
#
# To do so using `bdi-kit`, we can use the `match_schema()` function to match columns of the two schemas as follows. The `method` parameter allows modifying the schema matching algorithm used to perform the matching.
#
# ```python
# bdi.match_schema(df_source, df_target, method="jaccard_distance")
# bdi.match_schema(df_source, df_target, method="coma")
# bdi.match_schema(df_source, df_target, method="similarity_flooding")
# ```
#
# The method we use below is based on a pre-trained language model fine-tuned for the biomedical domain.
#
# For all methods available, see: [https://bdi-kit.readthedocs.io/en/latest/schema-matching.html](https://bdi-kit.readthedocs.io/en/latest/schema-matching.html)

# %%
schema_mapping = bdi.match_schema(df_source, df_target, method="max_val_sim")
schema_mapping.head(15)
# Out:
# Extracting features from 34 columns...
#   0%|          | 0/34 [00:00<?, ?it/s]
# Extracting features from 213 columns...
#   0%|          | 0/213 [00:00<?, ?it/s]
#                            source                                      target
# 0       Proteomics_Participant_ID                                     Case_id
# 1                   Case_excluded                               Case_excluded
# 2          Proteomics_TMT_channel                                ReporterName
# 3           Proteomics_Aliquot_ID                                  Aliquot_ID
# 4         Proteomics_Tumor_Normal                                       Group
# 5                         Country                         Participant_country
# 6                 Histologic_type                             Histologic_Type
# 7     Path_Stage_Primary_Tumor-pT         Pathologic_staging_primary_tumor_pt
# 8   Path_Stage_Reg_Lymph_Nodes-pN  Pathologic_staging_regional_lymph_nodes_pn
# 9         Clin_Stage_Dist_Mets-cM      Clinical_staging_distant_metastasis_cm
# 10       tumor_Stage-Pathological                    Tumor_stage_pathological
# 11                            BMI                                         BMI
# 12                            Age                                         Age
# 13                       Diabetes                                    Diabetes
# 14                           Race                                        Race

# %% [markdown]
# ### Inspecting values of each column

# %%
bdi.preview_domain(df_source, 'Proteomics_Participant_ID').head(5)
# Out:
#   value_name
# 0  C3L-00006
# 1  C3L-00008
# 2  C3L-00032
# 3  C3L-00084
# 4  C3L-00090

# %%
bdi.preview_domain(df_target, 'Case_id').head(5)
# Out:
#   value_name
# 0  C3L-00086
# 1  C3L-00898
# 2  C3L-00943
# 3  C3L-01064
# 4  C3L-01277

# %% [markdown]
# #### Finding value matches between two columns
#
# Once the matching columns are identified, we can standardize data to ensure that no duplicate values represent the same entity/meaning.
#
# To do that, `bdikit` provides the function `match_values()` to find values that should potentially be merged. The library supports multiple methods to perform this task, including syntactic and semantic matching algorithms. In this example, we use the `tfidf` method, which finds values based on the similarity of character n-grams. Please, refer to the [bdikit documentation](https://bdi-kit.readthedocs.io/) to learn more about the methods available.

# %%
# Matches values from each pair of source-target columns
value_matches = bdi.match_values(df_source, df_target, schema_mapping, method="tfidf")

# Print value matches
bdi.view_value_matches(value_matches, edit=False)
# Out:
# <br>**Source column:** Case_excluded<br>**Target column:** Case_excluded<br>
#   source target  similarity
# 0     No     No         1.0
# 1    Yes    Yes         1.0
# <br>**Source column:** Proteomics_TMT_channel<br>**Target column:** ReporterName<br>
#   source target  similarity
# 0   128N   128N       1.000
# 1   130N   130N       1.000
# 2   129N   129N       1.000
# 3   129C   129C       1.000
# 4   130C   130C       1.000
# 5   127N   127N       1.000
# 6   127C   127C       1.000
# 7   128C   128C       1.000
# 8    131   131N       0.714
# <br>**Source column:** Proteomics_Tumor_Normal<br>**Target column:** Group<br>
#               source           target  similarity
# 0              Tumor            Tumor         1.0
# 1    Adjacent_normal  Adjacent_normal         1.0
# 2    Enriched_normal  Enriched_Normal         1.0
# 3  Myometrium_normal              NaN         NaN
# <br>**Source column:** Country<br>**Target column:** Participant_country<br>
#           source         target  similarity
# 0  United States  United States         1.0
# 1            NaN            NaN         1.0
# 2        Ukraine        Ukraine         1.0
# 3         Poland         Poland         1.0
# 4  Other_specify            NaN         NaN
# <br>**Source column:** Histologic_type<br>**Target column:** Histologic_Type<br>
#            source                  target  similarity
# 0             NaN                     NaN       1.000
# 1    Endometrioid  Endometrioid carcinoma       0.855
# 2      Clear cell    Clear cell carcinoma       0.835
# 3          Serous        Serous carcinoma       0.717
# 4  Carcinosarcoma        Serous carcinoma       0.618
# <br>**Source column:** Path_Stage_Primary_Tumor-pT<br>**Target column:** Pathologic_staging_primary_tumor_pt<br>
#              source            target  similarity
# 0    pT1a (FIGO IA)    pT1a (FIGO IA)         1.0
# 1               NaN               NaN         1.0
# 2  pT3a (FIGO IIIA)  pT3a (FIGO IIIA)         1.0
# 3      pT1 (FIGO I)      pT1 (FIGO I)         1.0
# 4    pT1b (FIGO IB)    pT1b (FIGO IB)         1.0
# 5     pT2 (FIGO II)     pT2 (FIGO II)         1.0
# 6  pT3b (FIGO IIIB)  pT3b (FIGO IIIB)         1.0
# <br>**Source column:** Path_Stage_Reg_Lymph_Nodes-pN<br>**Target column:** Pathologic_staging_regional_lymph_nodes_pn<br>
#              source            target  similarity
# 0               pN0               pN0         1.0
# 1               pNX               pNX         1.0
# 2               NaN               NaN         1.0
# 3  pN2 (FIGO IIIC2)  pN2 (FIGO IIIC2)         1.0
# 4  pN1 (FIGO IIIC1)  pN1 (FIGO IIIC1)         1.0
# <br>**Source column:** Clin_Stage_Dist_Mets-cM<br>**Target column:** Clinical_staging_distant_metastasis_cm<br>
#                source              target  similarity
# 0                 cM0                 cM0         1.0
# 1                 NaN                 NaN         1.0
# 2  Staging Incomplete  Staging Incomplete         1.0
# 3                 cM1                 cM1         1.0
# <br>**Source column:** tumor_Stage-Pathological<br>**Target column:** Tumor_stage_pathological<br>
#       source     target  similarity
# 0    Stage I    Stage I         1.0
# 1   Stage IV   Stage IV         1.0
# 2        NaN        NaN         1.0
# 3  Stage III  Stage III         1.0
# 4   Stage II   Stage II         1.0
# <br>**Source column:** Diabetes<br>**Target column:** Diabetes<br>
#     source target  similarity
# 0      Yes    Yes         1.0
# 1      NaN    NaN         1.0
# 2  Unknown    NaN         NaN
# 3       No    NaN         NaN
# <br>**Source column:** Race<br>**Target column:** Race<br>
#                       source                     target  similarity
# 0                      White                      White         1.0
# 1                        NaN                        NaN         1.0
# 2                      Asian                      Asian         1.0
# 3               Not Reported               Not Reported         1.0
# 4  Black or African American  Black or African American         1.0
# <br>**Source column:** Ethnicity<br>**Target column:** Ethnicity<br>
#                    source                  target  similarity
# 0  Not-Hispanic or Latino  Not-Hispanic or Latino         1.0
# 1                     NaN                     NaN         1.0
# 2      Hispanic or Latino      Hispanic or Latino         1.0
# 3            Not reported            Not reported         1.0
# <br>**Source column:** Gender<br>**Target column:** Sex<br>
#    source  target  similarity
# 0  Female  Female         1.0
# 1     NaN     NaN         1.0
# <br>**Source column:** Tumor_Site<br>**Target column:** Tumor_site<br>
#                   source                 target  similarity
# 0   Anterior endometrium   Anterior endometrium       1.000
# 1  Posterior endometrium  Posterior endometrium       1.000
# 2                    NaN                    NaN       1.000
# 3         Other, specify                  Other       0.558
# <br>**Source column:** Tumor_Focality<br>**Target column:** Tumor_focality<br>
#        source      target  similarity
# 0    Unifocal    Unifocal         1.0
# 1         NaN         NaN         1.0
# 2  Multifocal  Multifocal         1.0
# <br>**Source column:** Estrogen_Receptor<br>**Target column:** Ancillary_studies_estrogen_receptor<br>
#                  source                target  similarity
# 0  Cannot be determined  Cannot be determined       1.000
# 1                   NaN                   NaN       1.000
# 2              Negative              Negative       1.000
# 3              Positive        Positive : 5 %       0.941
# 4               Unknown                   NaN         NaN
# <br>**Source column:** Progesterone_Receptor<br>**Target column:** Ancillary_studies_progesterone_receptor<br>
#                  source                target  similarity
# 0  Cannot be determined  Cannot be determined       1.000
# 1                   NaN                   NaN       1.000
# 2              Negative              Negative       1.000
# 3              Positive        Positive : 5 %       0.941
# 4               Unknown                   NaN         NaN
# <br>**Source column:** MLH1<br>**Target column:** Ancillary_studies_mlh1<br>
#                        source                      target  similarity
# 0   Intact nuclear expression   Intact nuclear expression         1.0
# 1                         NaN                         NaN         1.0
# 2  Loss of nuclear expression  Loss of nuclear expression         1.0
# 3        Cannot be determined        Cannot be determined         1.0
# 4                     Unknown                         NaN         NaN
# <br>**Source column:** PMS2<br>**Target column:** Ancillary_studies_pms2<br>
#                        source                      target  similarity
# 0   Intact nuclear expression   Intact nuclear expression         1.0
# 1  Loss of nuclear expression  Loss of nuclear expression         1.0
# 2                         NaN                         NaN         1.0
# 3        Cannot be determined        Cannot be determined         1.0
# 4                     Unknown                         NaN         NaN
# <br>**Source column:** p53<br>**Target column:** Ancillary_studies_p53<br>
#                  source                target  similarity
# 0  Cannot be determined  Cannot be determined         1.0
# 1                   NaN                   NaN         1.0
# 2                Normal                Normal         1.0
# 3        Overexpression        Overexpression         1.0
# 4    Loss of expression    Loss of expression         1.0
# 5               Unknown                   NaN         NaN
# <br>**Source column:** MLH1_Promoter_Hypermethylation<br>**Target column:** Ancillary_studies_mlh1_promoter_hypermethylation<br>
#                  source                target  similarity
# 0  Cannot be determined  Cannot be determined         1.0
# 1                   NaN                   NaN         1.0
# 2                Absent                Absent         1.0
# 3               Present               Present         1.0
# <br>**Source column:** Num_full_term_pregnancies<br>**Target column:** Donor_information_number_of_full_term_pregnancies<br>
#       source     target  similarity
# 0          1          1         1.0
# 1  4 or more  4 or more         1.0
# 2        NaN        NaN         1.0
# 3          2          2         1.0
# 4          3          3         1.0
# 5    Unknown    Unknown         1.0
# <br>**Source column:** CNV_class<br>**Target column:** CNV_status<br>
#      source target  similarity
# 0       NaN    NaN       1.000
# 1   CNV_LOW  CNV_L       0.631
# 2  CNV_HIGH  CNV_H       0.623
# <br>**Source column:** MSI_status<br>**Target column:** MSI_status<br>
#   source target  similarity
# 0  MSI-H  MSI-H         1.0
# 1    MSS    MSS         1.0
# 2    NaN    NaN         1.0
# <br>**Source column:** POLE_subtype<br>**Target column:** POLE<br>
#   source target  similarity
# 0     No     No         1.0
# 1    Yes    Yes         1.0
# 2    NaN    NaN         1.0
# <br>**Source column:** Genomics_subtype<br>**Target column:** Genomic_subtype<br>
#      source target  similarity
# 0     MSI-H  MSI-H       1.000
# 1       NaN    NaN       1.000
# 2      POLE   POLE       1.000
# 3   CNV_low  CNV_L       0.663
# 4  CNV_high  CNV_H       0.632

# %% [markdown]
# #### Generating a harmonized table

# %% [markdown]
# After verifying and fixing value mappings, we can proceed to generate a harmonized table.
#
# In bdikit, we can do this using the `bdi.materialize_mapping()` function.

# %%
df_mapped = bdi.materialize_mapping(df_source, value_matches)
df_mapped.head(5)
# Out:
#   Case_excluded ReporterName  Group Participant_country  \
# 0            No         128N  Tumor       United States
# 1            No         130N  Tumor       United States
# 2            No         131N  Tumor       United States
# 3           Yes         129N  Tumor                 NaN
# 4            No         129C  Tumor       United States
#
#           Histologic_Type Pathologic_staging_primary_tumor_pt  \
# 0  Endometrioid carcinoma                      pT1a (FIGO IA)
# 1  Endometrioid carcinoma                      pT1a (FIGO IA)
# 2  Endometrioid carcinoma                      pT1a (FIGO IA)
# 3        Serous carcinoma                                 NaN
# 4  Endometrioid carcinoma                      pT1a (FIGO IA)
#
#   Pathologic_staging_regional_lymph_nodes_pn  \
# 0                                        pN0
# 1                                        pNX
# 2                                        pN0
# 3                                        NaN
# 4                                        pNX
#
#   Clinical_staging_distant_metastasis_cm Tumor_stage_pathological Diabetes  \
# 0                                    cM0                  Stage I      NaN
# 1                                    cM0                 Stage IV      NaN
# 2                                    cM0                  Stage I      Yes
# 3                                    NaN                      NaN      NaN
# 4                                    cM0                  Stage I      NaN
#
#    ... Ancillary_studies_progesterone_receptor     Ancillary_studies_mlh1  \
# 0  ...                    Cannot be determined  Intact nuclear expression
# 1  ...                    Cannot be determined  Intact nuclear expression
# 2  ...                    Cannot be determined  Intact nuclear expression
# 3  ...                                     NaN                        NaN
# 4  ...                    Cannot be determined  Intact nuclear expression
#
#        Ancillary_studies_pms2 Ancillary_studies_p53  \
# 0   Intact nuclear expression  Cannot be determined
# 1  Loss of nuclear expression  Cannot be determined
# 2   Intact nuclear expression  Cannot be determined
# 3                         NaN                   NaN
# 4   Intact nuclear expression  Cannot be determined
#
#   Ancillary_studies_mlh1_promoter_hypermethylation  \
# 0                             Cannot be determined
# 1                             Cannot be determined
# 2                             Cannot be determined
# 3                                              NaN
# 4                             Cannot be determined
#
#   Donor_information_number_of_full_term_pregnancies CNV_status MSI_status  \
# 0                                                 1      CNV_L      MSI-H
# 1                                                 1      CNV_L      MSI-H
# 2                                         4 or more      CNV_L        MSS
# 3                                               NaN        NaN        MSS
# 4                                         4 or more      CNV_L        MSS
#
#   POLE Genomic_subtype
# 0   No           MSI-H
# 1   No           MSI-H
# 2   No           CNV_L
# 3   No             NaN
# 4   No           CNV_L
#
# [5 rows x 26 columns]

# %% [markdown]
# For comparisson sake, here is how these columns looked like in the original table:

# %%
source_column_names = list(map(lambda m: m.attrs['source'], value_matches))
target_column_names = list(map(lambda m: m.attrs['target'], value_matches))
df_source[source_column_names].head(5)
# Out:
#   Case_excluded Proteomics_TMT_channel Proteomics_Tumor_Normal        Country  \
# 0            No                   128N                   Tumor  United States
# 1            No                   130N                   Tumor  United States
# 2            No                    131                   Tumor  United States
# 3           Yes                   129N                   Tumor            NaN
# 4            No                   129C                   Tumor  United States
#
#   Histologic_type Path_Stage_Primary_Tumor-pT Path_Stage_Reg_Lymph_Nodes-pN  \
# 0    Endometrioid              pT1a (FIGO IA)                           pN0
# 1    Endometrioid              pT1a (FIGO IA)                           pNX
# 2    Endometrioid              pT1a (FIGO IA)                           pN0
# 3  Carcinosarcoma                         NaN                           NaN
# 4    Endometrioid              pT1a (FIGO IA)                           pNX
#
#   Clin_Stage_Dist_Mets-cM tumor_Stage-Pathological Diabetes  ...  \
# 0                     cM0                  Stage I       No  ...
# 1                     cM0                 Stage IV       No  ...
# 2                     cM0                  Stage I      Yes  ...
# 3                     NaN                      NaN      NaN  ...
# 4                     cM0                  Stage I       No  ...
#
#   Progesterone_Receptor                       MLH1  \
# 0  Cannot be determined  Intact nuclear expression
# 1  Cannot be determined  Intact nuclear expression
# 2  Cannot be determined  Intact nuclear expression
# 3                   NaN                        NaN
# 4  Cannot be determined  Intact nuclear expression
#
#                          PMS2                   p53  \
# 0   Intact nuclear expression  Cannot be determined
# 1  Loss of nuclear expression  Cannot be determined
# 2   Intact nuclear expression  Cannot be determined
# 3                         NaN                   NaN
# 4   Intact nuclear expression  Cannot be determined
#
#   MLH1_Promoter_Hypermethylation Num_full_term_pregnancies CNV_class  \
# 0           Cannot be determined                         1   CNV_LOW
# 1           Cannot be determined                         1   CNV_LOW
# 2           Cannot be determined                 4 or more   CNV_LOW
# 3                            NaN                       NaN       NaN
# 4           Cannot be determined                 4 or more   CNV_LOW
#
#   MSI_status POLE_subtype Genomics_subtype
# 0      MSI-H           No            MSI-H
# 1      MSI-H           No            MSI-H
# 2        MSS           No          CNV_low
# 3        MSS           No              NaN
# 4        MSS           No          CNV_low
#
# [5 rows x 26 columns]

# %% [markdown]
# The final step is to merge the two tables in a single harmonized dataset.

# %%
pd.concat([df_mapped[target_column_names], df_target[target_column_names]])
# Out:
#     Case_excluded ReporterName            Group Participant_country  \
# 0              No         128N            Tumor       United States
# 1              No         130N            Tumor       United States
# 2              No         131N            Tumor       United States
# 3             Yes         129N            Tumor                 NaN
# 4              No         129C            Tumor       United States
# ..            ...          ...              ...                 ...
# 185            No         129N  Enriched_Normal                 NaN
# 186            No         129C  Enriched_Normal                 NaN
# 187            No         129N  Enriched_Normal                 NaN
# 188            No         130C  Enriched_Normal                 NaN
# 189            No         131C  Enriched_Normal                 NaN
#
#             Histologic_Type Pathologic_staging_primary_tumor_pt  \
# 0    Endometrioid carcinoma                      pT1a (FIGO IA)
# 1    Endometrioid carcinoma                      pT1a (FIGO IA)
# 2    Endometrioid carcinoma                      pT1a (FIGO IA)
# 3          Serous carcinoma                                 NaN
# 4    Endometrioid carcinoma                      pT1a (FIGO IA)
# ..                      ...                                 ...
# 185                     NaN                                 NaN
# 186                     NaN                                 NaN
# 187                     NaN                                 NaN
# 188                     NaN                                 NaN
# 189                     NaN                                 NaN
#
#     Pathologic_staging_regional_lymph_nodes_pn  \
# 0                                          pN0
# 1                                          pNX
# 2                                          pN0
# 3                                          NaN
# 4                                          pNX
# ..                                         ...
# 185                                        NaN
# 186                                        NaN
# 187                                        NaN
# 188                                        NaN
# 189                                        NaN
#
#     Clinical_staging_distant_metastasis_cm Tumor_stage_pathological Diabetes  \
# 0                                      cM0                  Stage I      NaN
# 1                                      cM0                 Stage IV      NaN
# 2                                      cM0                  Stage I      Yes
# 3                                      NaN                      NaN      NaN
# 4                                      cM0                  Stage I      NaN
# ..                                     ...                      ...      ...
# 185                                    NaN                      NaN      NaN
# 186                                    NaN                      NaN      NaN
# 187                                    NaN                      NaN      NaN
# 188                                    NaN                      NaN      NaN
# 189                                    NaN                      NaN      NaN
#
#      ... Ancillary_studies_progesterone_receptor     Ancillary_studies_mlh1  \
# 0    ...                    Cannot be determined  Intact nuclear expression
# 1    ...                    Cannot be determined  Intact nuclear expression
# 2    ...                    Cannot be determined  Intact nuclear expression
# 3    ...                                     NaN                        NaN
# 4    ...                    Cannot be determined  Intact nuclear expression
# ..   ...                                     ...                        ...
# 185  ...                                     NaN                        NaN
# 186  ...                                     NaN                        NaN
# 187  ...                                     NaN                        NaN
# 188  ...                                     NaN                        NaN
# 189  ...                                     NaN                        NaN
#
#          Ancillary_studies_pms2 Ancillary_studies_p53  \
# 0     Intact nuclear expression  Cannot be determined
# 1    Loss of nuclear expression  Cannot be determined
# 2     Intact nuclear expression  Cannot be determined
# 3                           NaN                   NaN
# 4     Intact nuclear expression  Cannot be determined
# ..                          ...                   ...
# 185                         NaN                   NaN
# 186                         NaN                   NaN
# 187                         NaN                   NaN
# 188                         NaN                   NaN
# 189                         NaN                   NaN
#
#     Ancillary_studies_mlh1_promoter_hypermethylation  \
# 0                               Cannot be determined
# 1                               Cannot be determined
# 2                               Cannot be determined
# 3                                                NaN
# 4                               Cannot be determined
# ..                                               ...
# 185                                              NaN
# 186                                              NaN
# 187                                              NaN
# 188                                              NaN
# 189                                              NaN
#
#     Donor_information_number_of_full_term_pregnancies CNV_status MSI_status  \
# 0                                                   1      CNV_L      MSI-H
# 1                                                   1      CNV_L      MSI-H
# 2                                           4 or more      CNV_L        MSS
# 3                                                 NaN        NaN        MSS
# 4                                           4 or more      CNV_L        MSS
# ..                                                ...        ...        ...
# 185                                               NaN        NaN        NaN
# 186                                               NaN        NaN        NaN
# 187                                               NaN        NaN        NaN
# 188                                               NaN        NaN        NaN
# 189                                               NaN        NaN        NaN
#
#     POLE Genomic_subtype
# 0     No           MSI-H
# 1     No           MSI-H
# 2     No           CNV_L
# 3     No             NaN
# 4     No           CNV_L
# ..   ...             ...
# 185  NaN             NaN
# 186  NaN             NaN
# 187  NaN             NaN
# 188  NaN             NaN
# 189  NaN             NaN
#
# [343 rows x 26 columns]
